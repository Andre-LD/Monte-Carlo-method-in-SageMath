# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from math import e, pi, sqrt, cos
from sympy import Symbol

def ex1(x):
    return np.sqrt(1 - x**2)

def val_ex1():
    cod = 1
    a = 1
    b = 0
    n = 10**4
    y = [0, 1]
    print("Exercício - 1)\n")
    print("Valor esperado = 3.141593")
    return a, b, y, n, cod

def ex2(x):
    return x**2

def val_ex2():
    cod = 2
    a = 1
    b = 0
    n = 10**4
    y = [0, 1]
    print("Exercício - 2)\n")
    print("Valor esperado = 0.3333")
    return a, b, y, n, cod

def ex3(x):
    return x**3

def val_ex3():
    cod = 3
    a = 2
    b = 0
    n = 10**4
    y = [0, 8]
    print("Exercício - 3)\n")
    print("Valor esperado = 4")
    return a, b, y, n, cod

def ex4(x):
    return 1/x

def val_ex4():
    cod = 4
    a = e
    b = 1
    n = 10**4
    y = [0, 1 ]
    print("Exercício - 4)\n")
    print("Valor esperado = 1")
    return a, b, y, n, cod

def ex5(x):
    return np.sin(x)

def val_ex5():
    cod = 5
    a = pi
    b = 0
    n = 10**4
    y = [0, 1]
    print("Exercício - 5)\n")
    print('Valor esperado = ',float(1+cos(1)))
    return a, b, y, n, cod

def ex6(x):
    return 1/(1+x**2)

def val_ex6():
    cod = 6 # Retorna o codigo da Eq.
    a = 1
    b = 0
    n = 10**4
    y = [0, 1]
    print("Exercício - 6)\n")
    print("Valor esperado = 0.785")
    return a, b, y, n, cod

def ex7(x):
    return 1 / np.sqrt(1 - np.cos(x))

def val_ex7():
    cod = 7
    a = 2*(np.pi)
    b = 0
    n = 10**4
    y = [0, 800]
    print("Exercício - 7)\n")
    print("Valor esperado = 50.0")
    return a, b, y, n, cod

def ex8(x):
    return 1/(x**2+1)

def val_ex8():
    cod = 8 #
    a = 42
    b = 0
    n = 10**4
    y = [0, 1]
    print("Exercício - 8)\n")
    print("Valor esperado = 1.570797")
    return a, b, y, n, cod

def ex9(x):
    return e**x/ (1+e**x)

def val_ex9():
    cod = 9
    a = 1
    b = -1
    n = 10**4
    y = [0, 0.731059]
    print("Exercício - 9)\n")
    print("Valor esperado = 1")
    return a, b, y, n, cod

def ex10(x):
    return 1/sqrt(x)

def val_ex10():
    cod = 10
    a = 1
    b = 0
    n = 10**4
    y = [0, 10]
    print("Exercício - 10)\n")
    print("Valor esperado = 2")
    return a, b, y, n, cod

def nome_eq(num):
    x = Symbol('x')
    equação = ["f(x)=x**2",
               "f(x)=x**3",
               "f(x)=1/x",
               "f(x)=np.sin(x)",
               "f(x)=1/(1+x**2)",
               "f(x)=1/np.sqrt(1-np.cos(x))",
               "f(x)=1/(x**2+1)",
               "f(x)=e^x/ (1+e^x)",
               "f(x)=1/sqrt(x)"]
    return equação[num-2]

def calculadora(a, b, ym, Eq, y1, y2, cod):
    XD = np.linspace(float(a), b, 100)
    plt.figure()
    plt.plot(XD,Eq(XD))
    teste = 0
    underworld = 0
    for i in range(n):
        x = random.uniform(a, b)
        y = random.uniform(y1, y2)
        teste += 1
        print(str('Contador de interações ') + str(teste), end='\r')
        if y <= Eq(x):
            underworld = underworld + 1
            plt.scatter(x, y, color='b', s=2, alpha=0.5)
        else:
            plt.scatter(x, y, color='r', s=2, alpha=0.5)
    if cod == 1.0:
        solv = 4*(underworld/n) * (a - b) * (y2 - y1)
    else:
        solv = (underworld/n) * (a - b) * (y2 - y1)
    print("\nValor calculado =",float(solv))
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.plot(XD,Eq(XD),color='g',linewidth=0.9)
    plt.plot(x, y,color='green', label=nome_eq(cod))
    plt.xlabel('x')
    plt.ylabel('f(x)')
    plt.title("Gráfico do método de Monte Carlo")
    plt.legend()
    plt.show()
    return

a, b, ym, n, cod = val_ex1()
Eq = ex1
y1, y2 = ym[0], ym[1]
calculadora(a, b, ym, Eq, y1, y2, cod)

a, b, ym, n, cod = val_ex2()
Eq = ex2
y1, y2 = ym[0], ym[1]
calculadora(a, b, ym, Eq, y1, y2, cod)

a, b, ym, n, cod = val_ex3()
Eq = ex3
y1, y2 = ym[0], ym[1]
calculadora(a, b, ym, Eq, y1, y2, cod)

a, b, ym, n, cod = val_ex4()
Eq = ex4
y1, y2 = ym[0], ym[1]
calculadora(a, b, ym, Eq, y1, y2, cod)

a, b, ym, n, cod = val_ex5()
Eq = ex5
y1, y2 = ym[0], ym[1]
calculadora(a, b, ym, Eq, y1, y2, cod)

a, b, ym, n, cod = val_ex6()
Eq = ex6
y1, y2 = ym[0], ym[1]
calculadora(a, b, ym, Eq, y1, y2, cod)

a, b, ym, n, cod = val_ex7()
Eq = ex7
y1, y2 = ym[0], ym[1]
calculadora(a, b, ym, Eq, y1, y2, cod)

a, b, ym, n, cod = val_ex8()
Eq = ex8
y1, y2 = ym[0], ym[1]
calculadora(a, b, ym, Eq, y1, y2, cod)

a, b, ym, n, cod = val_ex9()
Eq = ex9
y1, y2 = ym[0], ym[1]
calculadora(a, b, ym, Eq, y1, y2, cod)

a, b, ym, n, cod = val_ex10()
Eq = ex10
y1, y2 = ym[0], ym[1]
calculadora(a, b, ym, Eq, y1, y2, cod)
# Out:
# Exercício - 1)
#
# Valor esperado = 3.141593
# Contador de interações 1000
# Valor calculado = 3.136
# Exercício - 2)
#
# Valor esperado = 0.3333
# Contador de interações 1000
# Valor calculado = 0.338
# Exercício - 3)
#
# Valor esperado = 4
# Contador de interações 1000
# Valor calculado = 4.432
# Exercício - 4)
#
# Valor esperado = 1
# Contador de interações 1671
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-4c615f386c5c> in <module>
#     198 Eq = ex4
#     199 y1, y2 = ym[Integer(0)], ym[Integer(1)]
# --> 200 calculadora(a, b, ym, Eq, y1, y2, cod)
#     201
#     202 a, b, ym, n, cod = val_ex5()
#
# <ipython-input-3-4c615f386c5c> in calculadora(a, b, ym, Eq, y1, y2, cod)
#     163             plt.scatter(x, y, color='b', s=Integer(2), alpha=RealNumber('0.5'))
#     164         else:
# --> 165             plt.scatter(x, y, color='r', s=Integer(2), alpha=RealNumber('0.5'))
#     166     if cod == RealNumber('1.0'):
#     167         solv = Integer(4)*(underworld/n) * (a - b) * (y2 - y1)
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2893         verts=verts, edgecolors=edgecolors,
#    2894         plotnonfinite=plotnonfinite,
# -> 2895         **({"data": data} if data is not None else {}), **kwargs)
#    2896     sci(__ret)
#    2897     return __ret
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4515                 self.set_ymargin(0.05)
#    4516
# -> 4517         self.add_collection(collection)
#    4518         self._request_autoscale_view()
#    4519
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/axes/_base.py in add_collection(self, collection, autolim)
#    1932             # Make sure viewLim is not stale (mostly to match
#    1933             # pre-lazy-autoscale behavior, which is not really better).
# -> 1934             self._unstale_viewLim()
#    1935             self.update_datalim(collection.get_datalim(self.transData))
#    1936
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/axes/_base.py in _unstale_viewLim(self)
#     645             for ax in self._shared_y_axes.get_siblings(self):
#     646                 ax._stale_viewlim_y = False
# --> 647             self.autoscale_view(scalex=scalex, scaley=scaley)
#     648
#     649     @property
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/axes/_base.py in autoscale_view(self, tight, scalex, scaley)
#    2496                 x_stickies = np.sort(np.concatenate([
#    2497                     artist.sticky_edges.x
# -> 2498                     for ax in self._shared_x_axes.get_siblings(self)
#    2499                     if hasattr(ax, "lines")
#    2500                     for artist in ax.get_children()]))
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# src/cysignals/signals.pyx in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:

# %%
print("Test")
